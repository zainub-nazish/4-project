# %% [markdown]
# <a href="https://colab.research.google.com/github/zainub-nazish/4-project/blob/main/Assignment_1_to_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("1-madlibs")


def mad_libs():
    print("Let's play Mad Libs! Fill in the blanks with your own words.")

    name = input("Give me a name: ")
    place = input("Give me a place: ")
    funny_adj = input("Give me a funny adjective: ")
    random_object = input("Give me a random object: ")
    animal = input("Give me an animal: ")
    action_verb = input("Give me an action verb: ")
    funny_exclamation = input("Give me a funny exclamation: ")

    story = f'''
    Once upon a time, there was a person named {name} who lived in {place}.
    One day, they found a {funny_adj} {random_object} that belonged to a {animal}.
    The {animal} was very upset and started to {action_verb} around.
    {name} couldn't help but laugh and shouted "{funny_exclamation}!"'''

    print("\nHere is your Mad Libs story:")
    print(story)

if __name__ == "__main__":
    mad_libs()
# Out:
# madlibs
# Let's play Mad Libs! Fill in the blanks with your own words.
# Give me a name: zainub
# Give me a place: house
# Give me a funny adjective: wobbly
# Give me a random object: toaster
# Give me an animal: lion
# Give me an action verb: breakdance
# Give me a funny exclamation: Great googly woogly
#
# Here is your Mad Libs story:
#
#     Once upon a time, there was a person named zainub who lived in house.
#     One day, they found a wobbly toaster that belonged to a lion.
#     The lion was very upset and started to breakdance around.
#     zainub couldn't help but laugh and shouted "Great googly woogly!"

# %%
print("2-guess-the-number(computer)")

import random
print("Welcome to the Number Guessing Game!")

low = 1
high = 10

print("Think of a number between 1 to 10 and computer will be guess it.")

if low <= high:
    guess = random.randint(low, high)
    print("Computer's guess is: ",guess)

    while True:
        feedback = input("Is the guess too high (H), too (L), or correct (C)? ").strip().upper()

        if feedback == 'C':
            print("Yay! The computer guessed your number ")
            break
        elif feedback == 'H':
            high = guess - 1
            guess = random.randint(low, high)
            print("Computer's guess is: ", guess)
        elif feedback == 'L':
            low = guess + 1
            guess = random.randint(low, high)
            print("Computer's guess is: ", guess)
        else:
            print("Invalid input. Please enter H, L, or C.")
if low > high:
    print("The number is not in the range. Please try again.")
# Out:
# 2-guess-the-number(computer)
# Welcome to the Number Guessing Game!
# Think of a number between 1 to 10 and computer will be guess it.
# Computer's guess is:  1
# Is the guess too high (H), too (L), or correct (C)? l
# Computer's guess is:  5
# Is the guess too high (H), too (L), or correct (C)? h
# Computer's guess is:  3
# Is the guess too high (H), too (L), or correct (C)? c
# Yay! The computer guessed your number

# %%
print("3-guess-the-number(user)")

import random

print("Welcome to the  Number Guessing Game!")

secret_number = random.randint(1, 10)
print("I have secret a number between 1 and 10.Can you guess it?")

while True:
    try:
        guess = int(input("Enter your guess: "))
        if guess > secret_number:
            print("To high! Try again.")
        elif guess < secret_number:
            print("To low! Try again.")
        else:
            print("Congratulation! You've guessed the number!")
            break

    except ValueError:
        print("Invalid input.Please enter a number between 1 and 10.")
# Out:
# 3-guess-the-number(user)
# Welcome to the  Number Guessing Game!
# I have secret a number between 1 and 10.Can you guess it?
# Enter your guess: 4
# To low! Try again.
# Enter your guess: 8
# To high! Try again.
# Enter your guess: 9
# To high! Try again.
# Enter your guess: 10
# To high! Try again.
# Enter your guess: 4
# To low! Try again.
# Enter your guess: 5
# Congratulation! You've guessed the number!

# %%
print("4-rock-paper-scissors")

import random
print("Welcome to the Rock, Paper, Scissors Game!")

choices = ["rock", "paper", "scissors"]
user_score = computer_score = 0
print("Let\'s  play!")

while True:
    user_input = input("Type Rock, Paper, Scissors or Q to quit: ").lower()
    if user_input == 'q':
        print(f'Final score - you: {user_score}, computer: {computer_score}')
        print("Thanks for playing!")
        break
    if user_input not in choices:
        print("Invalid input, please try again.")
        continue
    computer_chose = random.choices(choices)
    print(f"computer chose {computer_chose}.")
    if user_input == computer_chose:
        print("It's a tie!")
    elif (user_input == "rock" and computer_chose == "scissors") or \
          (user_input == "paper" and computer_chose == "rock") or \
          (user_input == "scissors" and computer_chose == "paper"):
        print("You Win!")
        user_score += 1
    else:
        print("Computer wins!")
        computer_score +=1

    print(f"Current score - you: {user_score}, computer: {computer_score}")
# Out:
# 4-rock-paper-scissors
# Welcome to the Rock, Paper, Scissors Game!
# Let's  play!
# computer chose ['scissors'].
# Computer wins!
# Current score - you: 0, computer: 1
# computer chose ['rock'].
# Computer wins!
# Current score - you: 0, computer: 2
# computer chose ['paper'].
# Computer wins!
# Current score - you: 0, computer: 3
# computer chose ['scissors'].
# Computer wins!
# Current score - you: 0, computer: 4
# computer chose ['rock'].
# Computer wins!
# Current score - you: 0, computer: 5
# computer chose ['scissors'].
# Computer wins!
# Current score - you: 0, computer: 6
# computer chose ['paper'].
# Computer wins!
# Current score - you: 0, computer: 7
# computer chose ['paper'].
# Computer wins!
# Current score - you: 0, computer: 8
# computer chose ['paper'].
# Computer wins!
# Current score - you: 0, computer: 9
# computer chose ['scissors'].
# Computer wins!
# Current score - you: 0, computer: 10
# computer chose ['paper'].
# Computer wins!
# Current score - you: 0, computer: 11

# %%
print("5-hangman")

import random

stages = ['''
    ---------
    |       |
    |
    |
    |
    |
     --------
''',
'''
    --------
    |       |
    |       O
    |
    |
    |
    --------
    ''',
    '''
    -------
    |      |
    |      O
    |      |
    |
    |
    --------
    ''',
    '''
    ---------
    |        |
    |        O
    |       /|
    |
    |
    ---------
    ''',
    '''
    ---------
    |        |
    |        O
    |       /|\\
    |
    |
    ---------
    ''',
    '''
    ---------
    |        |
    |        O
    |       /|\\
    |       /
    |
    ----------
    ''',
    '''
    ----------
    |         |
    |         O
    |        /|\\
    |        /  \\
    |
    ----------
    ''']

words =['apple','banana','orange','graph','watermelon','kiwi','mango','peach','pear','pulm','berry']

chosen_word = random.choice(words)
words_display = ['_' for _ in chosen_word]
guess_letters = []
lives = len(stages)-1

print("Welcome to Hangman!")
print("Guess the fruits word.")

while True:
    print(" ".join(words_display))
    guess = input("Guess a letter: ").lower()

    if not guess.isalpha() or len(guess) != 1:
        print("Please enter a valid letter.\n")
        continue
    if guess in guess_letters:
        print("You already guessed that letter. Try again.\n")
        continue

    guess_letters.append(guess)

    if guess in chosen_word:
        print(f"Good guess! '{guess}' is in the word.")
        for index, letter in enumerate(chosen_word):
            if letter == guess:
                words_display[index] = guess
    else:
        print(f"Sorry, '{guess}' is not in the word.")
        print(stages[len(stages) -lives -1])
        lives -= 1
        print(f"You have {lives} lives left.")

        if lives == 0:
            print(stages[lives])
            print(f"You lost! The word was '{chosen_word}'.")
            break
# Out:
# 5-hangman
# Welcome to Hangman!
# Guess the fruits word.
# _ _ _ _ _
# Good guess! 'a' is in the word.
# a _ _ _ _
# Good guess! 'p' is in the word.
# a p p _ _
# Good guess! 'l' is in the word.
# a p p l _
# Good guess! 'e' is in the word.
# a p p l e
# You already guessed that letter. Try again.
#
# a p p l e
# You already guessed that letter. Try again.
#
# a p p l e
# You already guessed that letter. Try again.
#
# a p p l e
# Sorry, 'c' is not in the word.
#
#     ---------
#     |       |
#     |
#     |
#     |
#     |
#      --------
#
# You have 5 lives left.
# a p p l e
# Sorry, 'h' is not in the word.
#
#     --------
#     |       |
#     |       O
#     |
#     |
#     |
#     --------
#
# You have 4 lives left.
# a p p l e
# Sorry, 'k' is not in the word.
#
#     -------
#     |      |
#     |      O
#     |      |
#     |
#     |
#     --------
#
# You have 3 lives left.
# a p p l e
# Sorry, 'i' is not in the word.
#
#     ---------
#     |        |
#     |        O
#     |       /|
#     |
#     |
#     ---------
#
# You have 2 lives left.
# a p p l e
# Sorry, 'w' is not in the word.
#
#     ---------
#     |        |
#     |        O
#     |       /|\
#     |
#     |
#     ---------
#
# You have 1 lives left.
# a p p l e
# You already guessed that letter. Try again.
#
# a p p l e

# %%
print("6-Countdown Timer")

import time

def countdown(seconds):
    mins = seconds // 60
    seconds = seconds % 60
    print(f'{mins:02d}:{seconds:02d}', end="\r")
    time.sleep(1)
    seconds -= 1

    if seconds >=0:
        countdown(seconds)
    else:
        print("Time's up!")

if __name__ == "__main__":
    countdown(10)
# Out:
# 6-Countdown Timer
# Time's up!

# %%
print("7-Password Generator")

import random
import string

def generate_password(length):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = "".join(random.choice(characters) for _ in range(length))
    return password

length = int(input("Enter the desired password length: "))

if __name__ == "__main__":
    print("Generated password:", generate_password(length))
# Out:
# 7-Password Generator
# Enter the desired password length: 7
# Generated password: F60j"Tf
